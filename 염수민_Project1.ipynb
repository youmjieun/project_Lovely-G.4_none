# %% [markdown]
# <a href="https://colab.research.google.com/github/suminyeom/project_Lovely-G.4_none/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
train= pd.read_csv('/content/drive/MyDrive/open/train.csv')
test= pd.read_csv('/content/drive/MyDrive/open/test.csv')
submission= pd.read_csv('/content/drive/MyDrive/open/sample_submission.csv')

# %%
train.head()
# Out:
#            ID  착과량(int)  수고(m)  수관폭1(min)  수관폭2(max)  수관폭평균  2022-09-01 새순  \
# 0  TRAIN_0000       692  275.0      287.0      292.0  289.5            2.8
# 1  TRAIN_0001       534  293.0      284.0      336.0  310.0            3.3
# 2  TRAIN_0002       634  300.0      392.0      450.0  421.0            3.0
# 3  TRAIN_0003       639  289.0      368.0      379.0  373.5            3.1
# 4  TRAIN_0004       496  306.0      353.0      358.0  355.5            3.7
#
#    2022-09-02 새순  2022-09-03 새순  2022-09-04 새순  ...  2022-11-19 엽록소  \
# 0            2.8            2.7            2.7  ...       70.978249
# 1            3.3            3.3            3.2  ...       71.535483
# 2            2.9            2.9            2.9  ...       71.279804
# 3            3.0            3.0            3.0  ...       69.934615
# 4            3.6            3.6            3.6  ...       68.313016
#
#    2022-11-20 엽록소  2022-11-21 엽록소  2022-11-22 엽록소  2022-11-23 엽록소  \
# ...

# %%
test.head()
# Out:
#           ID  수고(m)  수관폭1(min)  수관폭2(max)  수관폭평균  2022-09-01 새순  \
# 0  TEST_0000  231.0      219.0      302.0  260.5            4.3
# 1  TEST_0001  206.0      324.0      346.0  335.0            2.5
# 2  TEST_0002  282.0      373.0      404.0  388.5            4.7
# 3  TEST_0003  234.0      337.0      357.0  347.0            3.6
# 4  TEST_0004  222.0      329.0      347.0  338.0            2.7
#
#    2022-09-02 새순  2022-09-03 새순  2022-09-04 새순  2022-09-05 새순  ...  \
# 0            4.2            4.2            4.1            4.1  ...
# 1            2.5            2.5            2.5            2.5  ...
# 2            4.7            4.6            4.6            4.5  ...
# 3            3.6            3.6            3.6            3.5  ...
# 4            2.7            2.7            2.7            2.6  ...
#
#    2022-11-19 엽록소  2022-11-20 엽록소  2022-11-21 엽록소  2022-11-22 엽록소  \
# 0       72.091497       71.906176       71.886799       71.858720
# ...

# %%
submission.head()
# Out:
#           ID  착과량(int)
# 0  TEST_0000         0
# 1  TEST_0001         0
# 2  TEST_0002         0
# 3  TEST_0003         0
# 4  TEST_0004         0

# %%
print(train.shape)
print(test.shape)
print(submission.shape)
# Out:
# (2207, 184)
# (2208, 183)
# (2208, 2)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2207 entries, 0 to 2206
# Columns: 184 entries, ID to 2022-11-28 엽록소
# dtypes: float64(182), int64(1), object(1)
# memory usage: 3.1+ MB

# %%
train.isna().sum()
# Out:
# ID                0
# 착과량(int)          0
# 수고(m)             0
# 수관폭1(min)         0
# 수관폭2(max)         0
#                  ..
# 2022-11-24 엽록소    0
# 2022-11-25 엽록소    0
# 2022-11-26 엽록소    0
# 2022-11-27 엽록소    0
# 2022-11-28 엽록소    0
# Length: 184, dtype: int64

# %%
train.isna()
# Out:
#          ID  착과량(int)  수고(m)  수관폭1(min)  수관폭2(max)  수관폭평균  2022-09-01 새순  \
# 0     False     False  False      False      False  False          False
# 1     False     False  False      False      False  False          False
# 2     False     False  False      False      False  False          False
# 3     False     False  False      False      False  False          False
# 4     False     False  False      False      False  False          False
# ...     ...       ...    ...        ...        ...    ...            ...
# 2202  False     False  False      False      False  False          False
# 2203  False     False  False      False      False  False          False
# 2204  False     False  False      False      False  False          False
# 2205  False     False  False      False      False  False          False
# 2206  False     False  False      False      False  False          False
#
#       2022-09-02 새순  2022-09-03 새순  2022-09-04 새순  ...  2022-11-19 엽록소  \
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Columns: 183 entries, ID to 2022-11-28 엽록소
# dtypes: float64(182), object(1)
# memory usage: 3.1+ MB

# %%
test.isna().sum()
# Out:
# ID                0
# 수고(m)             0
# 수관폭1(min)         0
# 수관폭2(max)         0
# 수관폭평균             0
#                  ..
# 2022-11-24 엽록소    0
# 2022-11-25 엽록소    0
# 2022-11-26 엽록소    0
# 2022-11-27 엽록소    0
# 2022-11-28 엽록소    0
# Length: 183, dtype: int64

# %%
train.describe()
# Out:
#           착과량(int)       수고(m)    수관폭1(min)    수관폭2(max)        수관폭평균  \
# count  2207.000000  2207.00000  2207.000000  2207.000000  2207.000000
# mean    406.222474   243.72995   315.186226   358.824196   337.005211
# std     218.978302    35.88914    66.327994    68.862898    64.859684
# min       1.000000    95.00000    95.000000   123.000000   109.000000
# 25%     221.000000   223.00000   271.500000   313.500000   294.000000
# 50%     404.000000   243.00000   316.000000   364.000000   340.500000
# 75%     593.500000   267.00000   361.000000   402.000000   380.000000
# max     799.000000   381.00000   559.000000   584.000000   571.500000
#
#        2022-09-01 새순  2022-09-02 새순  2022-09-03 새순  2022-09-04 새순  \
# count    2207.000000    2207.000000    2207.000000    2207.000000
# mean        3.774807       3.736928       3.701495       3.663435
# std         0.774181       0.764067       0.754751       0.745394
# min         2.300000       2.200000       2.200000       2.200000
# ...

# %%
train['수고(m)'].describe()
# Out:
# count    2207.00000
# mean      243.72995
# std        35.88914
# min        95.00000
# 25%       223.00000
# 50%       243.00000
# 75%       267.00000
# max       381.00000
# Name: 수고(m), dtype: float64

# %%
#수고(m) 분포
train['수고(m)'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
train['착과량(int)'].describe()
# Out:
# count    2207.000000
# mean      406.222474
# std       218.978302
# min         1.000000
# 25%       221.000000
# 50%       404.000000
# 75%       593.500000
# max       799.000000
# Name: 착과량(int), dtype: float64

# %%
#착과량 분포
train['착과량(int)'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
train['수관폭평균'].describe()
# Out:
# count    2207.000000
# mean      337.005211
# std        64.859684
# min       109.000000
# 25%       294.000000
# 50%       340.500000
# 75%       380.000000
# max       571.500000
# Name: 수관폭평균, dtype: float64

# %%
#수관폭평균 분포
train['수관폭평균'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
train['수관폭1(min)'].describe()
# Out:
# count    2207.000000
# mean      315.186226
# std        66.327994
# min        95.000000
# 25%       271.500000
# 50%       316.000000
# 75%       361.000000
# max       559.000000
# Name: 수관폭1(min), dtype: float64

# %%
#수관폭1(min) 분포
train['수관폭1(min)'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
train['수관폭2(max)'].describe()
# Out:
# count    2207.000000
# mean      358.824196
# std        68.862898
# min       123.000000
# 25%       313.500000
# 50%       364.000000
# 75%       402.000000
# max       584.000000
# Name: 수관폭2(max), dtype: float64

# %%
#수관폭2(max) 분포
train['수관폭2(max)'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
train.groupby('착과량(int)').mean()
# Out:
# <ipython-input-23-26ce013d2e31>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   train.groupby('착과량(int)').mean()
#                수고(m)   수관폭1(min)   수관폭2(max)       수관폭평균  2022-09-01 새순  \
# 착과량(int)
# 1         245.666667  302.000000  336.333333  319.166667       5.066667
# 2         238.333333  341.666667  380.666667  361.166667       4.966667
# 3         247.000000  330.833333  370.333333  350.583333       5.066667
# 5         234.000000  367.000000  398.666667  382.833333       5.000000
# 6         266.500000  294.250000  370.500000  332.375000       5.050000
# ...              ...         ...         ...         ...            ...
# 794       238.000000  366.000000  467.000000  416.500000       2.500000
# 795       268.250000  334.500000  379.500000  357.000000       2.650000
# ...

# %%
#수고별 착과량
from matplotlib import pyplot as plt
_df_12['수고(m)'].plot(kind='hist', bins=20, title='수고(m)')
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#수관폭1(min)별 착과량
from matplotlib import pyplot as plt
_df_1['수관폭1(min)'].plot(kind='hist', bins=20, title='수관폭1(min)')
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 54253 (\N{HANGUL SYLLABLE POG}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
#수관폭2(max)별 착과량
from matplotlib import pyplot as plt
_df_2['수관폭2(max)'].plot(kind='hist', bins=20, title='수관폭2(max)')
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 54253 (\N{HANGUL SYLLABLE POG}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
#수관폭평균별 착과량
from matplotlib import pyplot as plt
_df_15['수관폭평균'].plot(kind='hist', bins=20, title='수관폭평균')
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 54253 (\N{HANGUL SYLLABLE POG}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lineplot(data=train , x="2022-09-01 새순", y="착과량(int)")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49352 (\N{HANGUL SYLLABLE SAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52265 (\N{HANGUL SYLLABLE CAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.lineplot(data=train , x="2022-11-28 새순", y="착과량(int)")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49352 (\N{HANGUL SYLLABLE SAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52265 (\N{HANGUL SYLLABLE CAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
